# %%
######################################################################
# UNIVERSIDADE FEDERAL DE CATALÃO (UFCAT)
# WANDERLEI MALAQUIAS PEREIRA JUNIOR,        ENG. CIVIL / PROF (UFCAT)
# ROMES ANTÔNIO BORGES,                            MATE / PROF (UFCAT)
# DONIZETTI APARECIDO DE S. JÚNIOR,                 ENG. CIVIL (UFCAT)
######################################################################

######################################################################
# DESCRIÇÃO ALGORITMO:
# BIBLIO. PRODES DE ALGORITMOS ESTOCÁSTICOS DE CONFIABILIDADE
######################################################################

################################################################################
# BIBLIOTECAS NATIVAS PYTHON
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

################################################################################
# BIBLIOTECAS DESENVOLVEDORES GPEE
def SAMPLING(VARIABLES):
    """
    THIS FUNCTION GENERATES RANDOM SAMPLES ACCORDING 
    TO CHOICE SAMPLING METHOD
    
    INPUT:
    VARIABLES: STOCHASTIC RANDOM VARIABLES DESCRIPTION, (DICTIONARY, MIXED)

        
    OUTPUT:
    RANDOM_SAMPLING: STOCHASTIC RANDOM SAMPLING, (NP.ARRAY, FLOAT)
    """
    # START RESERVED SPACE FOR SAMPLING
    N_SAMPLING = VARIABLES['TOTAL SAMPLING']
    D = len(VARIABLES['TYPE'])
    MODEL = VARIABLES['MODEL']
    RANDOM_SAMPLING = np.zeros((N_SAMPLING, D))
    if MODEL == 'MCS':
        for I_COUNT in range(D):
            # SETUP TYPE, MEAN AND STD I VARIABLE
            TYPE = VARIABLES['TYPE'][I_COUNT]
            MEAN = VARIABLES['MEAN'][I_COUNT]
            STD = VARIABLES['STD'][I_COUNT]
            # NORMAL AND GAUSSIAN DISTRIBUITION
            if (TYPE == 'GAUSSIAN' or TYPE == 'NORMAL'):
                RANDOM_NUMBERS = np.random.normal(MEAN, STD, N_SAMPLING)
                RANDOM_SAMPLING[:, I_COUNT] = RANDOM_NUMBERS
            # GUMBEL MAXIMUM DISTRIBUITION
            elif TYPE == 'GUMBEL MAX':
                RANDOM_NUMBERS = np.random.gumbel(MEAN, STD, N_SAMPLING)
                RANDOM_SAMPLING[:, I_COUNT] = RANDOM_NUMBERS
            # LOGNORMAL DISTRIBUITION
            elif TYPE == 'LOGNORMAL':
                RANDOM_NUMBERS = np.random.lognormal(MEAN, STD, N_SAMPLING)
                RANDOM_SAMPLING[:, I_COUNT] = RANDOM_NUMBERS
            # GAMMA DISTRIBUITION
            elif TYPE == 'GAMMA':
                RANDOM_NUMBERS = np.random.gamma(MEAN, STD, N_SAMPLING)
                RANDOM_SAMPLING[:, I_COUNT] = RANDOM_NUMBERS
            # DONIZETTI ADD OUTRAS DISTRIBUIÇÕES
            ####
            ####
            ####
            ####
            ####
    elif MODEL == 'LHS':
        pass
        # DONIZETTI ADD O LHS
        #####
        #####
        #####
    return RANDOM_SAMPLING

def GRAPHICS(DATA):
    """
    THIS FUNCTION GENERATES CHARTS AND SAVE IT
    
    INPUT:
    DATA: DATASET, (DICTIONARY, MIXED)

        
    OUTPUT:
    NONE
    
    """
    CHART_TYPE = DATA['TYPE CHART']
    DATASET = DATA['DATASET']
    if CHART_TYPE == 0:
        CHART_0(DATASET)
    return

def CHART_0(DATASET):
    """
    THIS PLOT CHART 0: HISTOGRAM + BOXPLOT
    """
    sns.set(style = "ticks")
    D = DATASET.shape[1]
    for I_COUNT in range(D):
        X = DATASET[:, I_COUNT]
        FIG, (AX_BOX, AX_HIST) = plt.subplots(2, sharex = True, gridspec_kw = {"height_ratios": (.15, .85)})
        sns.boxplot(X, ax = AX_BOX)
        sns.distplot(X, ax = AX_HIST)
        AX_BOX.set(yticks = [])
        sns.despine(ax = AX_HIST)
        sns.despine(ax = AX_BOX, left = True)
    return

# %%
# teste
VARIABLES = {'TYPE': ['NORMAL', 'LOGNORMAL', 'GUMBEL MAX'],
            'MEAN': [3, 4, 5],
            'STD': [.9, .8, 0.2],
            'TOTAL SAMPLING': 1000,
            'MODEL': 'MCS'}

wander = SAMPLING(VARIABLES)

DATA = {'NAME': 'doni',
        'TYPE CHART': 0,
        'DPI': 1600,
        'DATASET': wander}

GRAPHICS(DATA)

# %%
def RELIABILITY_ANALYSIS(SETUP, G):
    N_REP = SETUP['REPETITIONS']
    N_SAMPLING = SETUP['TOTAL SAMPLING'] 
    N_G = SETUP['TOTAL G FUNCTIONS'] 
    RESULTS = []
    for I_COUNT in range(N_REP):
        RESULTS_ITER = []
        for J_COUNT in range(N_SAMPLING):
            X = resulTS[j, :]

# %%
# programa
def G(X):
    return G

DIC = {'OF': G}
